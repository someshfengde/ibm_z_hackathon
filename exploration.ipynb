# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np 
import plotly.express as px 
import matplotlib.pyplot as plt 
import os 
import sys

# %% [markdown]
# # Reading the data

# %%
all_files = [f"./data/{x}" for x in os.listdir("./data")]

# %%
all_files
# Out:
# ['./data/2018_culprits_disposal.xlsx',
#  './data/2019_states_data.xlsx',
#  './data/2018_states_data.xlsx',
#  './data/2019_victims_rescued.xlsx',
#  './data/2020_victims_rescued.xlsx',
#  './data/2018_victims_trafficked.xlsx',
#  './data/2020_rescued_victims_nationality.xlsx',
#  './data/2018_victims_rescued.xlsx',
#  './data/2020_number_of_AHT_Units.xlsx',
#  './data/2019_victims_trafficked.xlsx',
#  './data/2018_police_and_court_disposal_of_cases.xlsx',
#  './data/2020_victims_trafficked.xlsx',
#  './data/2018_human_trafficking_purpose.xlsx',
#  './data/2020_case_disposal.xlsx',
#  './data/2019_culprits_disposal.xlsx',
#  './data/2018_rescued_victims_nationality.xlsx',
#  './data/2020_states_data.xlsx',
#  './data/2019_victims_rescued_nationality.xlsx',
#  './data/2019_trafficking_purpose.xlsx',
#  './data/2019_police_and_court_disposal.xlsx',
#  './data/2020_trafficking_purpose.xlsx',
#  './data/2020_culprits_disposal.xlsx']

# %%
states_data_18 =  pd.read_excel("./data/2018_states_data.xlsx")
victims_18 =  pd.read_excel("./data/2018_victims_trafficked.xlsx")
rescued_victims_18  =  pd.read_excel("./data/2018_victims_rescued.xlsx")
victims_nationality_18  =  pd.read_excel("./data/2018_rescued_victims_nationality.xlsx")
culprit_disposal_18  =  pd.read_excel("./data/2018_culprits_disposal.xlsx")
cases_disposal_18 =  pd.read_excel("./data/2018_police_and_court_disposal_of_cases.xlsx")
purpose_18 =  pd.read_excel("./data/2018_human_trafficking_purpose.xlsx")

#2019
states_data_19  =  pd.read_excel("./data/2019_states_data.xlsx")
victims_19 =  pd.read_excel("./data/2019_victims_trafficked.xlsx")
rescued_victims_19  =  pd.read_excel("./data/2019_victims_rescued.xlsx")
victims_nationality_19 =  pd.read_excel("./data/2019_victims_rescued_nationality.xlsx")
culprit_disposal_19 =  pd.read_excel("./data/2019_culprits_disposal.xlsx")
cases_disposal_19 =  pd.read_excel("./data/2019_police_and_court_disposal.xlsx")
purpose_19 =  pd.read_excel("./data/2019_trafficking_purpose.xlsx")

#2020
states_data_20 =  pd.read_excel("./data/2020_states_data.xlsx")
victims_20 =  pd.read_excel("./data/2020_victims_trafficked.xlsx")
rescued_victims_20 =  pd.read_excel("./data/2020_victims_rescued.xlsx")
victims_nationality_20=  pd.read_excel("./data/2020_rescued_victims_nationality.xlsx")
culprit_disposal_20 =  pd.read_excel("./data/2020_culprits_disposal.xlsx")
cases_disposal_20 =  pd.read_excel("./data/2020_case_disposal.xlsx")
purpose_20 =  pd.read_excel("./data/2020_trafficking_purpose.xlsx")
aht_units_20 =  pd.read_excel("./data/2020_number_of_AHT_Units.xlsx")

# %%
import skimpy

# %%
dataframe_names = pd.concat([states_data_18,victims_18, rescued_victims_18,victims_nationality_18,
                    culprit_disposal_18,cases_disposal_18,purpose_18,states_data_19,victims_19,rescued_victims_19,victims_nationality_19,
                    culprit_disposal_19,cases_disposal_19,purpose_19,states_data_20,victims_20,rescued_victims_20,victims_nationality_20,
                    culprit_disposal_20,cases_disposal_20,purpose_20,aht_units_20])

# %%
al_dfs = ["states_data_18","victims_18", "rescued_victims_18","victims_nationality_18",
                    "culprit_disposal_18","cases_disposal_18","purpose_18","states_data_19","victims_19","rescued_victims_19","victims_nationality_19",
                    "culprit_disposal_19","cases_disposal_19","purpose_19","states_data_20","victims_20","rescued_victims_20","victims_nationality_20",
                    "culprit_disposal_20","cases_disposal_20","purpose_20","aht_units_20"]

# %%
dataframe_names.columns
# Out:
# Index([' S. No. ', 'State/UT ', 'Cases Reported ',
#        'Percentage Share of State (2018) ',
#        'Mid-Year Projected Population (In Lakhs)+ ',
#        'Rate of Cognizable Crimes (IPC)++ ', 'region type', 'State/UT', 'Male',
#        'Female', 'Total_victims_trafficked', 'Age Group',
#        'Total_victims_rescued', 'region_type', 'Nationality',
#        'Persons Arrested ', 'Persons Chargesheeted ', 'Persons Convicted ',
#        'Persons Acquitted/ discharged by the Court ', 'states/UT',
#        'Total number of cases', 'cases chargesheeted by police',
#        'cases with final reports by police', 'chargesheeting rate',
#        'cases convicted by court', 'cases acquitted/discharged by court',
#        'cases in which trails were completed', 'cases conviction rate',
#        'Forced Labour ', 'Sexual Exploitation for Prostitution ',
#        'Domestic Servitude ', 'Forced Marriage ', 'Petty Crimes ',
#        'Child Pornography ', 'Begging ', 'Removal of Organs ',
# ...

# %%
print(dataframe_names["Total_victims_trafficked"].isna().sum())
print("1332 are total values and most of them are null so neglecting the cols")
# Out:
# 1116
# 1332 are total values and most of them are null so neglecting the cols

# %%
# victims count as per age group
fig = px.pie(victims_18, "Age Group" , title= "Victims count as per age group") 
fig.show()

# %%
fig = px.bar(dataframe_names, 'State/UT ', 'Cases Reported ', title= "Cases Reported as per state", color= "Cases Reported ")
fig.show()

# %%
fig = px.scatter(dataframe_names,
                'Mid-Year Projected Population (In Lakhs)+ ','Cases Reported ', 
                title= "Cases Reported vs Population in lakhs", color= "Cases Reported ")

fig.show()

# %%
# Out:
# Empty DataFrame
# ...

# %%
# import dash 
# import dash_core_components as dcc
# import dash_html_components as html
# from dash.dependencies import Input, Output
x = 18
px.imshow(eval(f"states_data_{x}").corr(), text_auto = True, title = f"states_data_{x}")

# %%
culprit_disposal_18
# Out:
#              State/UT   Persons Arrested   Persons Chargesheeted   \
# 0      Andhra Pradesh                 863                     487
# 1   Arunachal Pradesh                   3                       2
# 2                Assam                253                     130
# 3               Bihar                 337                     271
# 4        Chhattisgarh                  96                      92
# 5                 Goa                 106                     149
# 6             Gujarat                  38                      38
# 7             Haryana                  70                      65
# 8    Himachal Pradesh                  22                      22
# 9     Jammu & Kashmir                   6                       6
# 10           Jharkhand                261                     151
# 11          Karnataka                  81                      38
# 12             Kerala                 197                      84
# ...
